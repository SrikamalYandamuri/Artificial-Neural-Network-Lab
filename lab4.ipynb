# %% [markdown]
# <a href="https://colab.research.google.com/github/SrikamalYandamuri/Artificial-Neural-Network-Lab/blob/main/lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

def linear(x):
    return x

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def bipolar_sigmoid(x):
    return (2 / (1 + np.exp(-x))) - 1

def tanh(x):
    return np.tanh(x)

def relu(x):
    return np.maximum(0, x)

def leaky_relu(x, alpha=0.01):
    return np.where(x > 0, x, x * alpha)

def softplus(x):
    return np.log(1 + np.exp(x))

# Define the range of x
x = np.linspace(-10, 10, 100)

# Plotting
plt.figure(figsize=(15, 15))

plt.subplot(4, 2, 1)
plt.plot(x, linear(x), label='Linear')
plt.title('Linear')
plt.grid(True)

plt.subplot(4, 2, 2)
plt.plot(x, sigmoid(x), label='Sigmoid')
plt.title('Sigmoid')
plt.grid(True)

plt.subplot(4, 2, 3)
plt.plot(x, bipolar_sigmoid(x), label='Bipolar Sigmoid')
plt.title('Bipolar Sigmoid')
plt.grid(True)

plt.subplot(4, 2, 4)
plt.plot(x, tanh(x), label='Tanh')
plt.title('Tanh')
plt.grid(True)

plt.subplot(4, 2, 5)
plt.plot(x, relu(x), label='ReLU')
plt.title('ReLU')
plt.grid(True)

plt.subplot(4, 2, 6)
plt.plot(x, leaky_relu(x), label='Leaky ReLU')
plt.title('Leaky ReLU')
plt.grid(True)

plt.subplot(4, 2, 7)
plt.plot(x, softplus(x), label='Softplus')
plt.title('Softplus')
plt.grid(True)

plt.tight_layout()
plt.show()
